# %%
import os
from s3fs.core import S3FileSystem
from xml.etree import ElementTree as ET
import pandas as pd


os.environ['AWS_CONFIG_FILE'] = 'aws_config.ini'

fs = S3FileSystem(anon=False)
bucket = 'treetracker-training-images'
datadir = os.path.join(bucket, "PlantCLEF_2016")

# %%
def parse_xml_s3path(s3path):
    '''
    Parse and return a PlantCLEF XML file given a valid s3path
    '''
    if os.path.splitext(s3path)[1] == "xml": 
        with fs.open(s3path) as file:
            tree = ET.parse(file)
            species = tree.find("Species").text
            family = tree.find("Family").text
            genus = tree.find("Genus").text
            class_id = tree.find("ClassId").text
            obs_id = tree.find("ObservationId").text
            date = tree.find("Date").text
            role = tree.find("LearnTag").text
            latitude = tree.find("Latitude").text
            longitude = tree.find("Longitude").text
            return (role, obs_id, class_id, date, family, genus, species, latitude, longitude)
    else:
        pass

def generate_plantclef_csv():
    linkings = {}
    for f, e, d in fs.walk(datadir):
        for path in d:
            if os.path.splitext(path)[1] == ".jpg": # Image file
                base = os.path.splitext(path)[0]
                print (base , " being processed")
                fullpath = os.path.join(f, base)
                xmlpath = fullpath + ".xml"
                if not fs.exists(xmlpath):
                    print ("File ", xmlpath , " does not exist!")
                linkings [base] = parse_xml_s3path(xmlpath)

    linkings = pd.DataFrame(linkings, columns=["role", "obs_id", "class_id", "date", "family", "genus", "species", "latitude", "longitude"])
    linkings.to_csv("s3://" + datadir + "/plantclef.csv")

# %%
generate_plantclef_csv()
# Out:
# 1  being processed
# 10  being processed
# 1000  being processed
# 10000  being processed
# 100001  being processed
# 100003  being processed
# 100004  being processed
# 100005  being processed
# 100007  being processed
# 100009  being processed
# 10001  being processed
# 100011  being processed
# 100012  being processed
# 100014  being processed
# 100016  being processed
# 100017  being processed
# 100018  being processed
# 100019  being processed
# 10002  being processed
# 100022  being processed
# 100023  being processed
# 100025  being processed
# 100026  being processed
# 100028  being processed
# 10003  being processed
# 100030  being processed
# 100031  being processed
# 100032  being processed
# 100033  being processed
# 100034  being processed
# 100037  being processed
# 100038  being processed
# 100039  being processed
# 10004  being processed
# 100040  being processed
# 100041  being processed
# 100042  being processed
# 100043  being processed
# 100044  being processed
# 100046  being processed
# 100047  being processed
# 100048  being processed
# 100049  being processed
# 10005  being processed
# 100051  being processed
# 100052  being processed
# 100053  being processed
# 100054  being processed
# 100055  being processed
# 100056  being processed
# 100057  being processed
# 100059  being processed
# 10006  being processed
# 100062  being processed
# 100063  being processed
# 100064  being processed
# 100065  being processed
# 100066  being processed
# 100067  being processed
# 100068  being processed
# 100069  being processed
# 10007  being processed
# 100070  being processed
# 100071  being processed
# 100072  being processed
# 100073  being processed
# 100074  being processed
# 100075  being processed
# 100076  being processed
# 100077  being processed
# 100078  being processed
# 100079  being processed
# 10008  being processed
# 100080  being processed
# 100081  being processed
# 100082  being processed
# 100083  being processed
# 100085  being processed
# 100086  being processed
# 100087  being processed
# 100088  being processed
# 100089  being processed
# 10009  being processed
# 100091  being processed
# 100092  being processed
# 100093  being processed
# 100094  being processed
# 100095  being processed
# 100096  being processed
# 100097  being processed
# 100098  being processed
# 100099  being processed
# 1001  being processed
# 10010  being processed
# 100100  being processed
# 100101  being processed
# 100102  being processed
# 100103  being processed
# 100104  being processed
# 100105  being processed
# 100106  being processed
# 100107  being processed
# 100108  being processed
# 100109  being processed
# 10011  being processed
# 100110  being processed
# 100111  being processed
# 100112  being processed
# 100114  being processed
# 100115  being processed
# 100116  being processed
# 100117  being processed
# 100118  being processed
# 100119  being processed
# 100120  being processed
# 100121  being processed
# 100122  being processed
# 100123  being processed
# 100124  being processed
# 100125  being processed
# 100126  being processed
# 100127  being processed
# 100128  being processed
# 10013  being processed
# 100131  being processed
# 100132  being processed
# 100133  being processed
# 100134  being processed
# 100135  being processed
# 100137  being processed
# 100138  being processed
# 100139  being processed
# 10014  being processed
# 100140  being processed
# 100141  being processed
# 100142  being processed
# 100143  being processed
# 100144  being processed
# 100145  being processed
# 100146  being processed
# 100149  being processed
# 10015  being processed
# 100150  being processed
# 100151  being processed
# 100152  being processed
# 100153  being processed
# 100156  being processed
# 100157  being processed
# 100159  being processed
# 10016  being processed
# 100160  being processed
# 100161  being processed
# 100163  being processed
# 100164  being processed
# 100167  being processed
# 100168  being processed
# 100169  being processed
# 10017  being processed
# 100171  being processed
# 100172  being processed
# 100173  being processed
# 100174  being processed
# 100175  being processed
# 100176  being processed
# 100177  being processed
# 100178  being processed
# 10018  being processed
# 100181  being processed
# 100182  being processed
# 100185  being processed
# 100187  being processed
# 100188  being processed
# 10019  being processed
# 100190  being processed
# 100191  being processed
# 100192  being processed
# 100193  being processed
# 100194  being processed
# 100196  being processed
# 100197  being processed
# 100198  being processed
# 100199  being processed
# 1002  being processed
# 10020  being processed
# 100200  being processed
# 100201  being processed
# 100203  being processed
# 100204  being processed
# 100205  being processed
# 100206  being processed
# 100207  being processed
# 100208  being processed
# 100209  being processed
# 10021  being processed
# 100210  being processed
# 100211  being processed
# 100212  being processed
# 100213  being processed
# 100214  being processed
# 100215  being processed
# 100216  being processed
# 100217  being processed
# 100218  being processed
# 10022  being processed
# 100220  being processed
# 100221  being processed
# 100222  being processed
# 100223  being processed
# 100224  being processed
# 100225  being processed
# 100227  being processed
# 100228  being processed
# 100229  being processed
# 10023  being processed
# 100230  being processed
# 100232  being processed
# 100233  being processed
# 100234  being processed
# 100235  being processed
# 100236  being processed
# 100237  being processed
# 100240  being processed
# 100242  being processed
# 100243  being processed
# 100244  being processed
# 100245  being processed
# 100246  being processed
# 100247  being processed
# 100249  being processed
# 10025  being processed
# 100250  being processed
# 100251  being processed
# 100252  being processed
# 100253  being processed
# 100254  being processed
# 100255  being processed
# 100256  being processed
# 100257  being processed
# 100258  being processed
# 10026  being processed
# 100260  being processed
# 100261  being processed
# 100262  being processed
# 100263  being processed
# 100264  being processed
# 100265  being processed
# 100266  being processed
# 100267  being processed
# 100269  being processed
# 10027  being processed
# 100270  being processed
# 100271  being processed
# 100272  being processed
# 100273  being processed
# 100274  being processed
# 100275  being processed
# 100276  being processed
# 100277  being processed
# 100278  being processed
# 100279  being processed
# 10028  being processed
# 100280  being processed
# 100281  being processed
# 100282  being processed
# 100283  being processed
# 100284  being processed
# 100285  being processed
# 100286  being processed
# 100287  being processed
# 100288  being processed
# 100289  being processed
# 10029  being processed
# 100291  being processed
# 100292  being processed
# 100293  being processed
# 100294  being processed
# 100295  being processed
# 100296  being processed
# 100298  being processed
# 100299  being processed
# 10030  being processed
# 100300  being processed
# 100301  being processed
# 100303  being processed
# 100305  being processed
# 100306  being processed
# 100307  being processed
# 100308  being processed
# 100309  being processed
# 10031  being processed
# 100310  being processed
# 100311  being processed
# 100312  being processed
# 100313  being processed
# 100315  being processed
# 100316  being processed
# 100317  being processed
# 100318  being processed
# 100319  being processed
# 10032  being processed
# 100320  being processed
# 100321  being processed
# 100323  being processed
# 100324  being processed
# 100325  being processed
# 100326  being processed
# 100327  being processed
# 100329  being processed
# 10033  being processed
# 100330  being processed
# 100331  being processed
# 100332  being processed
# 100333  being processed
# 100334  being processed
# 100335  being processed
# 100336  being processed
# 100337  being processed
# 100339  being processed
# 10034  being processed
# 100340  being processed
# 100341  being processed
# 100342  being processed
# 100343  being processed
# 100344  being processed
# 100345  being processed
# 100346  being processed
# 100347  being processed
# 100349  being processed
# 100350  being processed
# 100353  being processed
# 100355  being processed
# 100356  being processed
# 100357  being processed
# 100359  being processed
# 10036  being processed
# 100360  being processed
# 100361  being processed
# 100363  being processed
# 100364  being processed
# 100365  being processed
# 100366  being processed
# 100367  being processed
# 100368  being processed
# 100369  being processed
# 10037  being processed
# 100371  being processed
# 100373  being processed
# 100374  being processed
# 100375  being processed
# 100376  being processed
# 100377  being processed
# 100378  being processed
# 100379  being processed
# 100380  being processed
# 100381  being processed
# 100382  being processed
# 100383  being processed
# 100384  being processed
# 100385  being processed
# 100386  being processed
# 100387  being processed
# 100388  being processed
# 10039  being processed
# 100390  being processed
# 100391  being processed
# 100392  being processed
# 100393  being processed
# 100395  being processed
# 100396  being processed
# 100397  being processed
# 100398  being processed
# 100399  being processed
# 1004  being processed
# 10040  being processed
# 100400  being processed
# 100401  being processed
# 100402  being processed
# 100403  being processed
# 100404  being processed
# 100405  being processed
# 100406  being processed
# 100407  being processed
# 100408  being processed
# 100409  being processed
# 10041  being processed
# 100410  being processed
# 100412  being processed
# 100413  being processed
# 100414  being processed
# 100415  being processed
# 100416  being processed
# 100417  being processed
# 100418  being processed
# 100419  being processed
# 10042  being processed
# 100420  being processed
# 100421  being processed
# 100422  being processed
# 100423  being processed
# 100425  being processed
# 100426  being processed
# 100427  being processed
# 100429  being processed
# 100430  being processed
# 100431  being processed
# 100432  being processed
# 100433  being processed
# 100434  being processed
# 100435  being processed
# 100437  being processed
# 100438  being processed
# 100439  being processed
# 100441  being processed
# 100442  being processed
# 100443  being processed
# 100445  being processed
# 100446  being processed
# 100447  being processed
# 10045  being processed
# 100450  being processed
# 100451  being processed
# 100452  being processed
# 100454  being processed
# 100455  being processed
# 100457  being processed
# 100458  being processed
# 100459  being processed
# 10046  being processed
# 100461  being processed
# 100462  being processed
# 100463  being processed
# 100464  being processed
# 100465  being processed
# 100466  being processed
# 100467  being processed
# 100469  being processed
# 10047  being processed
# 100470  being processed
# 100471  being processed
# 100472  being processed
# 100473  being processed
# 100476  being processed
# 100477  being processed
# 100478  being processed
# 100479  being processed
# 10048  being processed
# 100480  being processed
# 100481  being processed
# 100482  being processed
# 100483  being processed
# 100484  being processed
# 100485  being processed
# 100486  being processed
# 100487  being processed
# 100488  being processed
# 100489  being processed
# 100490  being processed
# 100491  being processed
# 100492  being processed
# 100493  being processed
# 100494  being processed
# 100496  being processed
# 100498  being processed
# 100499  being processed
# 1005  being processed
# 10050  being processed
# 100500  being processed
# 100501  being processed
# 100502  being processed
# 100503  being processed
# 100504  being processed
# 100505  being processed
# 100506  being processed
# 100507  being processed
# 100508  being processed
# 100509  being processed
# 10051  being processed
# 100510  being processed
# 100514  being processed
# 100515  being processed
# 100517  being processed
# 100518  being processed
# 100519  being processed
# 100520  being processed
# 100523  being processed
# 100525  being processed
# 100526  being processed
# 100527  being processed
# 100528  being processed
# 100529  being processed
# 10053  being processed
# 100530  being processed
# 100531  being processed
# 100532  being processed
# 100533  being processed
# 100534  being processed
# 100535  being processed
# 100536  being processed
# 100537  being processed
# 100538  being processed
# 100539  being processed
# 10054  being processed
# 100540  being processed
# 100541  being processed
# 100543  being processed
# 100544  being processed
# 100545  being processed
# 100546  being processed
# 100547  being processed
# 100548  being processed
# 100549  being processed
# 10055  being processed
# 100550  being processed
# 100551  being processed
# 100552  being processed
# 100553  being processed
# 100555  being processed
# 100556  being processed
# 100557  being processed
# 100559  being processed
# 10056  being processed
# 100560  being processed
# 100562  being processed
# 100563  being processed
# 100564  being processed
# 100566  being processed
# 100567  being processed
# 100568  being processed
# 100569  being processed
# 100570  being processed
# 100571  being processed
# 100572  being processed
# 100573  being processed
# 100576  being processed
# 100577  being processed
# 100579  being processed
# 10058  being processed
# 100580  being processed
# 100581  being processed
# 100583  being processed
# 100584  being processed
# 100585  being processed
# 100586  being processed
# 100588  being processed
# 100589  being processed
# 10059  being processed
# 100590  being processed
# 100591  being processed
# 100592  being processed
# 100593  being processed
# 100594  being processed
# 100595  being processed
# 100596  being processed
# 100598  being processed
# 100599  being processed
# 1006  being processed
# 10060  being processed
# 100600  being processed
# 100601  being processed
# 100602  being processed
# 100603  being processed
# 100604  being processed
# 100605  being processed
# 100606  being processed
# 100607  being processed
# 100608  being processed
# 100609  being processed
# 10061  being processed
# 100610  being processed
# 100611  being processed
# 100613  being processed
# 100617  being processed
# 100618  being processed
# 10062  being processed
# 100620  being processed
# 100621  being processed
# 100622  being processed
# 100623  being processed
# 100624  being processed
# 100625  being processed
# 100628  being processed
# 10063  being processed
# 100631  being processed
# 100632  being processed
# 100633  being processed
# 100634  being processed
# 100635  being processed
# 100636  being processed
# 100639  being processed
# 10064  being processed
# 100642  being processed
# 100643  being processed
# 100644  being processed
# 100645  being processed
# 100646  being processed
# 100647  being processed
# 100648  being processed
# 10065  being processed
# 100651  being processed
# 100652  being processed
# 100653  being processed
# 100655  being processed
# 100656  being processed
# 100657  being processed
# 100659  being processed
# 10066  being processed
# 100660  being processed
# 100661  being processed
# 100662  being processed
# 100663  being processed
# 100664  being processed
# 100665  being processed
# 100666  being processed
# 100667  being processed
# 100668  being processed
# 100669  being processed
# 10067  being processed
# 100672  being processed
# 100673  being processed
# 100675  being processed
# 100676  being processed
# 100677  being processed
# 100678  being processed
# 100679  being processed
# 10068  being processed
# 100680  being processed
# 100681  being processed
# 100682  being processed
# 100685  being processed
# 100686  being processed
# 100687  being processed
# 100688  being processed
# 100689  being processed
# 10069  being processed
# 100690  being processed
# 100691  being processed
# 100692  being processed
# 100693  being processed
# 100695  being processed
# 100696  being processed
# 100697  being processed
# 100700  being processed
# 100701  being processed
# 100702  being processed
# 100703  being processed
# 100704  being processed
# 100705  being processed
# 100706  being processed
# 100707  being processed
# 100708  being processed
# 100709  being processed
# 10071  being processed
# 100711  being processed
# 100713  being processed
# 100714  being processed
# 100715  being processed
# 100716  being processed
# 10072  being processed
# 100720  being processed
# 100721  being processed
# 100722  being processed
# 100723  being processed
# 100724  being processed
# 100725  being processed
# 100726  being processed
# 100727  being processed
# 100728  being processed
# 100730  being processed
# 100731  being processed
# 100732  being processed
# 100733  being processed
# 100734  being processed
# 100735  being processed
# 100736  being processed
# 100737  being processed
# 100738  being processed
# 100739  being processed
# 10074  being processed
# 100740  being processed
# 100742  being processed
# 100743  being processed
# 100745  being processed
# 100746  being processed
# 100747  being processed
# 100748  being processed
# 100749  being processed
# 10075  being processed
# 100750  being processed
# 100751  being processed
# 100752  being processed
# 100753  being processed
# 100754  being processed
# 100755  being processed
# 100756  being processed
# 100759  being processed
# 10076  being processed
# 100762  being processed
# 100763  being processed
# 100764  being processed
# 100765  being processed
# 100766  being processed
# 100767  being processed
# 100768  being processed
# 100769  being processed
# 100770  being processed
# 100771  being processed
# 100772  being processed
# 100773  being processed
# 100774  being processed
# 100775  being processed
# 100776  being processed
# 100777  being processed
# 100778  being processed
# 100779  being processed
# 10078  being processed
# 100780  being processed
# 100781  being processed
# 100782  being processed
# 100786  being processed
# 100787  being processed
# 100788  being processed
# 100789  being processed
# 100790  being processed
# 100791  being processed
# 100792  being processed
# 100793  being processed
# 100794  being processed
# 100795  being processed
# 100797  being processed
# 100798  being processed
# 100799  being processed
# 1008  being processed
# 100800  being processed
# 100802  being processed
# 100803  being processed
# 100806  being processed
# 100807  being processed
# 100808  being processed
# 100809  being processed
# 10081  being processed
# 100810  being processed
# 100811  being processed
# 100812  being processed
# 100813  being processed
# 100814  being processed
# 100815  being processed
# 100816  being processed
# 100817  being processed
# 100818  being processed
# 100819  being processed
# 10082  being processed
# 100820  being processed
# 100821  being processed
# 100822  being processed
# 100823  being processed
# 100824  being processed
# 100825  being processed
# 100826  being processed
# 100828  being processed
# 10083  being processed
# 100831  being processed
# 100832  being processed
# 100833  being processed
# 100834  being processed
# 100835  being processed
# 100836  being processed
# 100837  being processed
# 100838  being processed
# 100839  being processed
# 10084  being processed
# 100840  being processed
# 100841  being processed
# 100842  being processed
# 100845  being processed
# 100846  being processed
# 100848  being processed
# 100849  being processed
# 100850  being processed
# 100851  being processed
# 100852  being processed
# 100853  being processed
# 100855  being processed
# 100856  being processed
# 100858  being processed
# 10086  being processed
# 100860  being processed
# 100861  being processed
# 100862  being processed
# 100865  being processed
# 100866  being processed
# 100867  being processed
# 100868  being processed
# 100869  being processed
# 100870  being processed
# 100872  being processed
# 100873  being processed
# 100874  being processed
# 100875  being processed
# 100876  being processed
# 100877  being processed
# 100878  being processed
# 100879  being processed
# 10088  being processed
# 100880  being processed
# 100881  being processed
# 100882  being processed
# 100883  being processed
# 100885  being processed
# 100886  being processed
# 100887  being processed
# 100888  being processed
# 10089  being processed
# 100890  being processed
# 100891  being processed
# 100892  being processed
# 100893  being processed
# 100894  being processed
# 100895  being processed
# 100896  being processed
# 100897  being processed
# 100898  being processed
# 100899  being processed
# 1009  being processed
# 10090  being processed
# 100901  being processed
# 100902  being processed
# 100903  being processed
# 100904  being processed
# 100905  being processed
# 100906  being processed
# 100907  being processed
# 100908  being processed
# 10091  being processed
# 100910  being processed
# 100911  being processed
# 100912  being processed
# 100913  being processed
# 100914  being processed
# 100915  being processed
# 100916  being processed
# 100917  being processed
# 100918  being processed
# 100919  being processed
# 100920  being processed
# 100921  being processed
# 100922  being processed
# 100924  being processed
# 100925  being processed
# 100927  being processed
# 100929  being processed
# 10093  being processed
# 100930  being processed
# 100931  being processed
# 100932  being processed
# 100933  being processed
# 100934  being processed
# 100935  being processed
# 100936  being processed
# 100937  being processed
# 100938  being processed
# 100939  being processed
# 10094  being processed
# 100940  being processed
# 100941  being processed
# 100943  being processed
# 100945  being processed
# 100946  being processed
# 100947  being processed
# 100948  being processed
# 100951  being processed
# 100952  being processed
# 100954  being processed
# 100955  being processed
# 100956  being processed
# 100957  being processed
# 100958  being processed
# 100960  being processed
# 100962  being processed
# 100963  being processed
# 100964  being processed
# 100965  being processed
# 100966  being processed
# 100967  being processed
# 100968  being processed
# 100970  being processed
# 100972  being processed
# 100973  being processed
# 100974  being processed
# 100975  being processed
# 100977  being processed
# 100978  being processed
# 100979  being processed
# 10098  being processed
# 100980  being processed
# 100981  being processed
# 100982  being processed
# 100983  being processed
# 100984  being processed
# 100985  being processed
# 100986  being processed
# 100987  being processed
# 100988  being processed
# 10099  being processed
# 100990  being processed
# 100991  being processed
# 100992  being processed
# 100993  being processed
# 100995  being processed
# 100996  being processed
# 100998  being processed
# 100999  being processed
# 101  being processed
# 10100  being processed
# 101001  being processed
# 101002  being processed
# 101003  being processed
# 101004  being processed
# 101008  being processed
# 101009  being processed
# 10101  being processed
# 101010  being processed
# 101011  being processed
# 101012  being processed
# 101014  being processed
# 101015  being processed
# 101016  being processed
# 101017  being processed
# 101018  being processed
# 10102  being processed
# 101020  being processed
# 101021  being processed
# 101022  being processed
# 101023  being processed
# 101024  being processed
# 101025  being processed
# 101026  being processed
# 101027  being processed
# 101028  being processed
# 101029  being processed
# 10103  being processed
# 101030  being processed
# 101031  being processed
# 101032  being processed
# 101033  being processed
# 101034  being processed
# 101035  being processed
# 101036  being processed
# 101037  being processed
# 101038  being processed
# 101039  being processed
# 10104  being processed
# 101040  being processed
# 101041  being processed
# 101042  being processed
# 101043  being processed
# 101044  being processed
# 101045  being processed
# 101046  being processed
# 101048  being processed
# 101049  being processed
# 10105  being processed
# 101051  being processed
# 101052  being processed
# 101053  being processed
# 101054  being processed
# 101055  being processed
# 101056  being processed
# 101057  being processed
# 101058  being processed
# 10106  being processed
# 101060  being processed
# 101061  being processed
# 101062  being processed
# 101063  being processed
# 101064  being processed
# 101065  being processed
# 101066  being processed
# 101067  being processed
# 101068  being processed
# 101069  being processed
# 10107  being processed
# 101070  being processed
# 101071  being processed
# 101073  being processed
# 101074  being processed
# 101075  being processed
# 101076  being processed
# 101077  being processed
# 101078  being processed
# 101079  being processed
# 10108  being processed
# 101080  being processed
# 101081  being processed
# 101082  being processed
# 101083  being processed
# 101084  being processed
# 101085  being processed
# 101086  being processed
# 101087  being processed
# 101088  being processed
# 101089  being processed
# 10109  being processed
# 101090  being processed
# 101091  being processed
# 101092  being processed
# 101093  being processed
# 101094  being processed
# 101095  being processed
# 101096  being processed
# 101097  being processed
# 101098  being processed
# 1011  being processed
# 10110  being processed
# 101100  being processed
# 101102  being processed
# 101103  being processed
# 101104  being processed
# 101105  being processed
# 101106  being processed
# 101107  being processed
# 101108  being processed
# 101109  being processed
# 10111  being processed
# 101111  being processed
# 101113  being processed
# 101114  being processed
# 101115  being processed
# 101116  being processed
# 101117  being processed
# 101118  being processed
# 101120  being processed
# 101121  being processed
# 101122  being processed
# 101123  being processed
# 101125  being processed
# 101126  being processed
# 101127  being processed
# 101128  being processed
# 101129  being processed
# 101130  being processed
# 101131  being processed
# 101132  being processed
# 101133  being processed
# 101134  being processed
# 101135  being processed
# 101136  being processed
# 101137  being processed
# 101138  being processed
# 101139  being processed
# 10114  being processed
# 101140  being processed
# 101141  being processed
# 101143  being processed
# 101145  being processed
# 101146  being processed
# 101147  being processed
# 101148  being processed
# 101149  being processed
# 10115  being processed
# 101150  being processed
# 101151  being processed
# 101152  being processed
# 101153  being processed
# 101154  being processed
# 101155  being processed
# 101158  being processed
# 10116  being processed
# 101160  being processed
# 101161  being processed
# 101162  being processed
# 101163  being processed
# 101164  being processed
# 101166  being processed
# 101167  being processed
# 101168  being processed
# 101169  being processed
# 101170  being processed
# 101171  being processed
# 101172  being processed
# 101173  being processed
# 101174  being processed
# 101175  being processed
# 101176  being processed
# 101177  being processed
# 101178  being processed
# 101179  being processed
# 10118  being processed
# 101180  being processed
# 101182  being processed
# 101183  being processed
# 101184  being processed
# 101185  being processed
# 101187  being processed
# 101188  being processed
# 101189  being processed
# 10119  being processed
# 101190  being processed
# 101191  being processed
# 101193  being processed
# 101196  being processed
# 101198  being processed
# 101199  being processed
# 1012  being processed
# 10120  being processed
# 101201  being processed
# 101203  being processed
# 101204  being processed
# 101206  being processed
# 101207  being processed
# 101208  being processed
# 10121  being processed
# 101210  being processed
# 101211  being processed
# 101212  being processed
# 101213  being processed
# 101214  being processed
# 101215  being processed
# 101217  being processed
# 101218  being processed
# 101219  being processed
# 10122  being processed
# 101220  being processed
# 101221  being processed
# 101222  being processed
# 101223  being processed
# 101224  being processed
# 101225  being processed
# 101226  being processed
# 101228  being processed
# 10123  being processed
# 101230  being processed
# 101233  being processed
# 101234  being processed
# 101235  being processed
# 101236  being processed
# 101237  being processed
# 101238  being processed
# 101239  being processed
# 10124  being processed
# 101240  being processed
# 101241  being processed
# 101242  being processed
# 101243  being processed
# 101244  being processed
# 101245  being processed
# 101246  being processed
# 101247  being processed
# 101249  being processed
# 10125  being processed
# 101250  being processed
# 101252  being processed
# 101253  being processed
# 101254  being processed
# 101255  being processed
# 101256  being processed
# 101257  being processed
# 101258  being processed
# 101259  being processed
# 10126  being processed
# 101261  being processed
# 101263  being processed
# 101264  being processed
# 101265  being processed
# 101267  being processed
# 101268  being processed
# 10127  being processed
# 101270  being processed
# 101271  being processed
# 101272  being processed
# 101273  being processed
# 101274  being processed
# 101275  being processed
# 101277  being processed
# 101278  being processed
# 101279  being processed
# 10128  being processed
# 101280  being processed
# 101285  being processed
# 101286  being processed
# 101288  being processed
# 101289  being processed
# 10129  being processed
# 101290  being processed
# 101291  being processed
# 101292  being processed
# 101295  being processed
# 101296  being processed
# 101297  being processed
# 101298  being processed
# 101300  being processed
# 101301  being processed
# 101303  being processed
# 101304  being processed
# 101305  being processed
# 101306  being processed
# 101307  being processed
# 101308  being processed
# 101309  being processed
# 101310  being processed
# 101311  being processed
# 101313  being processed
# 101314  being processed
# 101315  being processed
# 101316  being processed
# 101317  being processed
# 101318  being processed
# 101320  being processed
# 101321  being processed
# 101324  being processed
# 101325  being processed
# 101326  being processed
# 101327  being processed
# 101329  being processed
# 10133  being processed
# 101330  being processed
# 101331  being processed
# 101332  being processed
# 101333  being processed
# 101334  being processed
# 101336  being processed
# 101337  being processed
# 101338  being processed
# 101339  being processed
# 10134  being processed
# 101340  being processed
# 101341  being processed
# 101342  being processed
# 101343  being processed
# 101345  being processed
# 101346  being processed
# 101347  being processed
# 101348  being processed
# 101349  being processed
# 10135  being processed
# 101350  being processed
# 101351  being processed
# 101354  being processed
# 101355  being processed
# 101356  being processed
# 101358  being processed
# 101359  being processed
# 10136  being processed
# 101360  being processed
# 101362  being processed
# 101363  being processed
# 101365  being processed
# 101366  being processed
# 101367  being processed
# 101368  being processed
# 101369  being processed
# 10137  being processed
# 101370  being processed
# 101371  being processed
# 101372  being processed
# 101374  being processed
# 101375  being processed
# 101376  being processed
# 101377  being processed
# 101379  being processed
# 101380  being processed
# 101381  being processed
# 101382  being processed
# 101383  being processed
# 101384  being processed
# 101385  being processed
# 101386  being processed
# 101387  being processed
# 101388  being processed
# 101389  being processed
# 10139  being processed
# 101390  being processed
# 101391  being processed
# 101392  being processed
# 101393  being processed
# 101395  being processed
# 101396  being processed
# 101397  being processed
# 10140  being processed
# 101400  being processed
# 101403  being processed
# 101404  being processed
# 101405  being processed
# 101407  being processed
# 101408  being processed
# 101409  being processed
# 10141  being processed
# 101412  being processed
# 101416  being processed
# 101417  being processed
# 101418  being processed
# 101419  being processed
# 10142  being processed
# 101420  being processed
# 101421  being processed
# 101422  being processed
# 101423  being processed
# 101424  being processed
# 101425  being processed
# 101427  being processed
# 101428  being processed
# 101429  being processed
# 10143  being processed
# 101430  being processed
# 101431  being processed
# 101433  being processed
# 101434  being processed
# 101435  being processed
# 101436  being processed
# 101437  being processed
# 101438  being processed
# 10144  being processed
# 101440  being processed
# 101441  being processed
# 101442  being processed
# 101443  being processed
# 101444  being processed
# 101445  being processed
# 101446  being processed
# 101447  being processed
# 101448  being processed
# 101449  being processed
# 10145  being processed
# 101450  being processed
# 101453  being processed
# 101454  being processed
# 101455  being processed
# 101456  being processed
# 101457  being processed
# 101458  being processed
# 101459  being processed
# 101460  being processed
# 101461  being processed
# 101462  being processed
# 101463  being processed
# 101464  being processed
# 101465  being processed
# 101466  being processed
# 101467  being processed
# 101468  being processed
# 101469  being processed
# 10147  being processed
# 101472  being processed
# 101473  being processed
# 101474  being processed
# 101475  being processed
# 101477  being processed
# 101478  being processed
# 101479  being processed
# 10148  being processed
# 101480  being processed
# 101481  being processed
# 101482  being processed
# 101483  being processed
# 101484  being processed
# 101485  being processed
# 101486  being processed
# 101487  being processed
# 101488  being processed
# 101489  being processed
# 10149  being processed
# 101490  being processed
# 101491  being processed
# 101492  being processed
# 101493  being processed
# 101494  being processed
# 101495  being processed
# 101496  being processed
# 101497  being processed
# 101498  being processed
# 101499  being processed
# 1015  being processed
# 10150  being processed
# 101500  being processed
# 101501  being processed
# 101503  being processed
# 101504  being processed
# 101505  being processed
# 101506  being processed
# 101507  being processed
# 101509  being processed
# 10151  being processed
# 101510  being processed
# 101511  being processed
# 101512  being processed
# 101513  being processed
# 101514  being processed
# 101515  being processed
# 101516  being processed
# 101517  being processed
# 101518  being processed
# 101519  being processed
# 10152  being processed
# 101521  being processed
# 101523  being processed
# 101526  being processed
# 101528  being processed
# 101529  being processed
# 10153  being processed
# 101530  being processed
# 101531  being processed
# 101532  being processed
# 101533  being processed
# 101534  being processed
# 101535  being processed
# 101536  being processed
# 101537  being processed
# 10154  being processed
# 101541  being processed
# 101542  being processed
# 101543  being processed
# 101544  being processed
# 101545  being processed
# 101546  being processed
# 101548  being processed
# 101549  being processed
# 10155  being processed
# 101550  being processed
# 101551  being processed
# 101552  being processed
# 101553  being processed
# 101555  being processed
# 101556  being processed
# 101557  being processed
# 101559  being processed
# 10156  being processed
# 101560  being processed
# 101562  being processed
# 101563  being processed
# 101564  being processed
# 101565  being processed
# 101566  being processed
# 101568  being processed
# 101569  being processed
# 10157  being processed
# 101570  being processed
# 101571  being processed
# 101573  being processed
# 101576  being processed
# 101578  being processed
# 101579  being processed
# 10158  being processed
# 101580  being processed
# 101581  being processed
# 101582  being processed
# 101585  being processed
# 101586  being processed
# 101587  being processed
# 101588  being processed
# 101589  being processed
# 10159  being processed
# 101590  being processed
# 101591  being processed
# 101592  being processed
# 101593  being processed
# 101594  being processed
# 101595  being processed
# 101596  being processed
# 101597  being processed
# 101598  being processed
# 10160  being processed
# 101600  being processed
# 101601  being processed
# 101602  being processed
# 101603  being processed
# 101604  being processed
# 101605  being processed
# 101606  being processed
# 101607  being processed
# 101608  being processed
# 101609  being processed
# 101610  being processed
# 101611  being processed
# 101612  being processed
# 101613  being processed
# 101616  being processed
# 101617  being processed
# 101618  being processed
# 101619  being processed
# 10162  being processed
# 101620  being processed
# 101621  being processed
# 101622  being processed
# 101623  being processed
# 101624  being processed
# 101625  being processed
# 101626  being processed
# 101627  being processed
# 101628  being processed
# 101629  being processed
# 10163  being processed
# 101631  being processed
# 101632  being processed
# 101634  being processed
# 101635  being processed
# 101636  being processed
# 101637  being processed
# 101638  being processed
# 101639  being processed
# 101643  being processed
# 101644  being processed
# 101645  being processed
# 101646  being processed
# 101647  being processed
# 101648  being processed
# 101649  being processed
# 10165  being processed
# 101650  being processed
# 101651  being processed
# 101652  being processed
# 101653  being processed
# 101654  being processed
# 101655  being processed
# 101656  being processed
# 101657  being processed
# 101659  being processed
# 10166  being processed
# 101660  being processed
# 101661  being processed
# 101662  being processed
# 101663  being processed
# 101664  being processed
# 101665  being processed
# 101666  being processed
# 101667  being processed
# 101668  being processed
# 101669  being processed
# 101670  being processed
# 101671  being processed
# 101672  being processed
# 101674  being processed
# 101675  being processed
# 101676  being processed
# 101677  being processed
# 101678  being processed
# 101679  being processed
# 101680  being processed
# 101681  being processed
# 101682  being processed
# 101684  being processed
# 101687  being processed
# 101688  being processed
# 101689  being processed
# 101690  being processed
# 101691  being processed
# 101692  being processed
# 101693  being processed
# 101694  being processed
# 101695  being processed
# 101697  being processed
# 101699  being processed
# 10170  being processed
# 101701  being processed
# 101702  being processed
# 101704  being processed
# 101705  being processed
# 101707  being processed
# 101708  being processed
# 101709  being processed
# 101711  being processed
# 101712  being processed
# 101713  being processed
# 101715  being processed
# 101716  being processed
# 101717  being processed
# 101718  being processed
# 101719  being processed
# 10172  being processed
# 101720  being processed
# 101721  being processed
# 101722  being processed
# 101724  being processed
# 101725  being processed
# 101726  being processed
# 101727  being processed
# 101728  being processed
# 101729  being processed
# 10173  being processed
# 101730  being processed
# 101731  being processed
# 101732  being processed
# 101733  being processed
# 101734  being processed
# 101736  being processed
# 101737  being processed
# 101738  being processed
# 101739  being processed
# 10174  being processed
# 101740  being processed
# 101741  being processed
# 101742  being processed
# 101744  being processed
# 101746  being processed
# 101747  being processed
# 101748  being processed
# 101749  being processed
# 10175  being processed
# 101750  being processed
# 101751  being processed
# 101752  being processed
# 101753  being processed
# 101754  being processed
# 101755  being processed
# 101756  being processed
# 101757  being processed
# 101759  being processed
# 10176  being processed
# 101761  being processed
# 101762  being processed
# 101763  being processed
# 101764  being processed
# 101765  being processed
# 101766  being processed
# 101767  being processed
# 101768  being processed
# 101769  being processed
# 10177  being processed
# 101770  being processed
# 101771  being processed
# 101772  being processed
# 101773  being processed
# 101775  being processed
# 101776  being processed
# 101777  being processed
# 101778  being processed
# 10178  being processed
# 101780  being processed
# 101781  being processed
# 101783  being processed
# 101784  being processed
# 101785  being processed
# 101786  being processed
# 101787  being processed
# 101788  being processed
# 101789  being processed
# 10179  being processed
# 101790  being processed
# 101791  being processed
# 101792  being processed
# 101793  being processed
# 101794  being processed
# 101795  being processed
# 101797  being processed
# 101798  being processed
# 101799  being processed
# 1018  being processed
# 10180  being processed
# 101800  being processed
# 101801  being processed
# 101802  being processed
# 101803  being processed
# 101804  being processed
# 101805  being processed
# 101806  being processed
# 101807  being processed
# 101808  being processed
# 10181  being processed
# 101810  being processed
# 101811  being processed
# 101812  being processed
# 101813  being processed
# 101815  being processed
# 101816  being processed
# 101817  being processed
# 101818  being processed
# 10182  being processed
# 101820  being processed
# 101822  being processed
# 101824  being processed
# 101825  being processed
# 101826  being processed
# 101827  being processed
# 101828  being processed
# 10183  being processed
# 101831  being processed
# 101832  being processed
# 101833  being processed
# 101834  being processed
# 101835  being processed
# 101836  being processed
# 101837  being processed
# 101838  being processed
# 101839  being processed
# 10184  being processed
# 101840  being processed
# 101842  being processed
# 101843  being processed
# 101845  being processed
# 101846  being processed
# 101847  being processed
# 101848  being processed
# 101849  being processed
# 10185  being processed
# 101851  being processed
# 101852  being processed
# 101853  being processed
# 101854  being processed
# 101856  being processed
# 101857  being processed
# 101858  being processed
# 101859  being processed
# 10186  being processed
# 101860  being processed
# 101862  being processed
# 101863  being processed
# 101864  being processed
# 101866  being processed
# 101868  being processed
# 101869  being processed
# 10187  being processed
# 101870  being processed
# 101873  being processed
# 101874  being processed
# 101876  being processed
# 101877  being processed
# 101878  being processed
# 101879  being processed
# 10188  being processed
# 101880  being processed
# 101881  being processed
# 101882  being processed
# 101883  being processed
# 101885  being processed
# 101886  being processed
# 101888  being processed
# 101889  being processed
# 10189  being processed
# 101890  being processed
# 101891  being processed
# 101892  being processed
# 101893  being processed
# 101894  being processed
# 101896  being processed
# 101897  being processed
# 101898  being processed
# 1019  being processed
# 10190  being processed
# 101900  being processed
# 101901  being processed
# 101902  being processed
# 101903  being processed
# 101904  being processed
# 101905  being processed
# 101906  being processed
# 101907  being processed
# 101908  being processed
# 101909  being processed
# 10191  being processed
# 101910  being processed
# 101911  being processed
# 101913  being processed
# 101914  being processed
# 101915  being processed
# 101916  being processed
# 101917  being processed
# 101918  being processed
# 101920  being processed
# 101921  being processed
# 101922  being processed
# 101924  being processed
# 101925  being processed
# 101927  being processed
# 101928  being processed
# 101929  being processed
# 10193  being processed
# 101930  being processed
# 101931  being processed
# 101933  being processed
# 101934  being processed
# 101935  being processed
# 101936  being processed
# 101937  being processed
# 101938  being processed
# 101939  being processed
# 10194  being processed
# 101940  being processed
# 101942  being processed
# 101943  being processed
# 101946  being processed
# 101947  being processed
# 101948  being processed
# 101949  being processed
# 10195  being processed
# 101950  being processed
# 101951  being processed
# 101952  being processed
# 101953  being processed
# 101954  being processed
# 101955  being processed
# 101956  being processed
# 101957  being processed
# 101959  being processed
# 101960  being processed
# 101961  being processed
# 101962  being processed
# 101963  being processed
# 101965  being processed
# 101967  being processed
# 101968  being processed
# 10197  being processed
# 101970  being processed
# 101971  being processed
# 101972  being processed
# 101973  being processed
# 101975  being processed
# 101976  being processed
# 101977  being processed
# 101978  being processed
# 10198  being processed
# 101981  being processed
# 101983  being processed
# 101984  being processed
# 101985  being processed
# 101987  being processed
# 101988  being processed
# 101989  being processed
# 10199  being processed
# 101990  being processed
# 101991  being processed
# 101992  being processed
# 101993  being processed
# 101994  being processed
# 101995  being processed
# 101996  being processed
# 101997  being processed
# 101998  being processed
# 102  being processed
# 1020  being processed
# 10200  being processed
# 102000  being processed
# 102001  being processed
# 102003  being processed
# 102004  being processed
# 102006  being processed
# 102009  being processed
# 102011  being processed
# 102012  being processed
# 102013  being processed
# 102014  being processed
# 102015  being processed
# 102016  being processed
# 102017  being processed
# 102019  being processed
# 10202  being processed
# 102021  being processed
# 102022  being processed
# 102023  being processed
# 102024  being processed
# 102025  being processed
# 102026  being processed
# 102027  being processed
# 102028  being processed
# 10203  being processed
# 102030  being processed
# 102031  being processed
# 102032  being processed
# 102033  being processed
# 102034  being processed
# 102035  being processed
# 102037  being processed
# 102038  being processed
# 102039  being processed
# 10204  being processed
# 102040  being processed
# 102041  being processed
# 102042  being processed
# 102043  being processed
# 102044  being processed
# 102045  being processed
# 102046  being processed
# 102047  being processed
# 10205  being processed
# 102052  being processed
# 102053  being processed
# 102054  being processed
# 102058  being processed
# 102059  being processed
# 102060  being processed
# 102061  being processed
# 102062  being processed
# 102063  being processed
# 102064  being processed
# 102065  being processed
# 102066  being processed
# 102067  being processed
# 102069  being processed
# 10207  being processed
# 102070  being processed
# 102072  being processed
# 102073  being processed
# 102074  being processed
# 102075  being processed
# 102076  being processed
# 102077  being processed
# 102078  being processed
# 102079  being processed
# 10208  being processed
# 102080  being processed
# 102081  being processed
# 102083  being processed
# 102084  being processed
# 102085  being processed
# 102086  being processed
# 102087  being processed
# 102088  being processed
# 102089  being processed
# 10209  being processed
# 102090  being processed
# 102091  being processed
# 102092  being processed
# 102093  being processed
# 102094  being processed
# 102095  being processed
# 102096  being processed
# 102099  being processed
# 1021  being processed
# 10210  being processed
# 102101  being processed
# 102102  being processed
# 102103  being processed
# 102106  being processed
# 102108  being processed
# 102109  being processed
# 10211  being processed
# 102110  being processed
# 102111  being processed
# 102112  being processed
# 102113  being processed
# 102114  being processed
# 102116  being processed
# 102117  being processed
# 102118  being processed
# 102119  being processed
# 10212  being processed
# 102120  being processed
# 102122  being processed
# 102123  being processed
# 102124  being processed
# 102125  being processed
# 102126  being processed
# 102127  being processed
# 102128  being processed
# 10213  being processed
# 102130  being processed
# 102131  being processed
# 102132  being processed
# 102133  being processed
# 102135  being processed
# 102136  being processed
# 102137  being processed
# 102139  being processed
# 10214  being processed
# 102140  being processed
# 102141  being processed
# 102142  being processed
# 102143  being processed
# 102144  being processed
# 102145  being processed
# 102146  being processed
# 102147  being processed
# 102148  being processed
# 102149  being processed
# 10215  being processed
# 102150  being processed
# 102151  being processed
# 102153  being processed
# 102155  being processed
# 102156  being processed
# 102157  being processed
# 102158  being processed
# 102160  being processed
# 102161  being processed
# 102163  being processed
# 102164  being processed
# 102165  being processed
# 102167  being processed
# 102168  being processed
# 102169  being processed
# 102170  being processed
# 102171  being processed
# 102172  being processed
# 102174  being processed
# 102176  being processed
# 102178  being processed
# 10218  being processed
# 102180  being processed
# 102181  being processed
# 102182  being processed
# 102185  being processed
# 102186  being processed
# 102187  being processed
# 102189  being processed
# 10219  being processed
# 102190  being processed
# 102191  being processed
# 102192  being processed
# 102193  being processed
# 102194  being processed
# 102197  being processed
# 102198  being processed
# 1022  being processed
# 10220  being processed
# 102200  being processed
# 102202  being processed
# 102204  being processed
# 102205  being processed
# 102206  being processed
# 102208  being processed
# 102209  being processed
# 10221  being processed
# ...
# 22912  being processed
# 22913  being processed
# 22915  being processed
# 22916  being processed
# 22917  being processed
# 22918  being processed
# 22919  being processed
# 2292  being processed
# 22920  being processed
# 22921  being processed
# 22922  being processed
# 22923  being processed
# 22924  being processed
# 22927  being processed
# 22928  being processed
# 22929  being processed
# 2293  being processed
# 22930  being processed
# 22931  being processed
# 22932  being processed
# 22933  being processed
# 22935  being processed
# 22936  being processed
# 22937  being processed
# 22938  being processed
# 22939  being processed
# 22940  being processed
# 22941  being processed
# 22942  being processed
# 22943  being processed
# 22944  being processed
# 22945  being processed
# 22946  being processed
# 22947  being processed
# 22948  being processed
# 22949  being processed
# 2295  being processed
# 22951  being processed
# 22952  being processed
# 22953  being processed
# 22954  being processed
# 22955  being processed
# 22956  being processed
# 22957  being processed
# 22958  being processed
# 22959  being processed
# 2296  being processed
# 22960  being processed
# 22961  being processed
# 22962  being processed
# 22964  being processed
# 22967  being processed
# 22968  being processed
# 22969  being processed
# 2297  being processed
# 22970  being processed
# 22971  being processed
# 22972  being processed
# 22975  being processed
# 22977  being processed
# 22978  being processed
# 22979  being processed
# 2298  being processed
# 22980  being processed
# 22981  being processed
# 22982  being processed
# 22983  being processed
# 22984  being processed
# 22986  being processed
# 22987  being processed
# 22988  being processed
# 22989  being processed
# 22990  being processed
# 22991  being processed
# 22992  being processed
# 22993  being processed
# 22994  being processed
# 22996  being processed
# 22997  being processed
# 22999  being processed
# 23  being processed
# 2300  being processed
# 23000  being processed
# 23001  being processed
# 23002  being processed
# 23004  being processed
# 23005  being processed
# 23006  being processed
# 23007  being processed
# 23009  being processed
# 23010  being processed
# 23011  being processed
# 23012  being processed
# 23013  being processed
# 23014  being processed
# 23015  being processed
# 23016  being processed
# 23017  being processed
# 23019  being processed
# 23021  being processed
# 23022  being processed
# 23023  being processed
# 23024  being processed
# 23026  being processed
# 23027  being processed
# 23028  being processed
# 23029  being processed
# 2303  being processed
# 23030  being processed
# 23031  being processed
# 23032  being processed
# 23033  being processed
# 23036  being processed
# 23039  being processed
# 2304  being processed
# 23040  being processed
# 23042  being processed
# 23043  being processed
# 23044  being processed
# 23045  being processed
# 23046  being processed
# 23047  being processed
# 23048  being processed
# 23049  being processed
# 2305  being processed
# 23050  being processed
# 23051  being processed
# 23052  being processed
# 23053  being processed
# 23055  being processed
# 23058  being processed
# 2306  being processed
# 23060  being processed
# 23061  being processed
# 23062  being processed
# 23063  being processed
# 23064  being processed
# 23065  being processed
# 23066  being processed
# 23067  being processed
# 23068  being processed
# 2307  being processed
# 23070  being processed
# 23071  being processed
# 23072  being processed
# 23073  being processed
# 23074  being processed
# 23075  being processed
# 23076  being processed
# 23077  being processed
# 23079  being processed
# 2308  being processed
# 23080  being processed
# 23082  being processed
# 23083  being processed
# 23085  being processed
# 23086  being processed
# 23087  being processed
# 23088  being processed
# 2309  being processed
# 23090  being processed
# 23091  being processed
# 23092  being processed
# 23093  being processed
# 23094  being processed
# 23095  being processed
# 23097  being processed
# 23098  being processed
# 23099  being processed
# 231  being processed
# 2310  being processed
# 23100  being processed
# 23101  being processed
# 23102  being processed
# 23103  being processed
# 23105  being processed
# 23106  being processed
# 23107  being processed
# 23109  being processed
# 2311  being processed
# 23110  being processed
# 23111  being processed
# 23113  being processed
# 23115  being processed
# 23116  being processed
# 23117  being processed
# 23118  being processed
# 23119  being processed
# 2312  being processed
# 23121  being processed
# 23123  being processed
# 23124  being processed
# 23127  being processed
# 23129  being processed
# 2313  being processed
# 23131  being processed
# 23132  being processed
# 23133  being processed
# 23135  being processed
# 23136  being processed
# 23137  being processed
# 23139  being processed
# 2314  being processed
# 23140  being processed
# 23141  being processed
# 23142  being processed
# 23145  being processed
# 23146  being processed
# 23147  being processed
# 23148  being processed
# 23149  being processed
# 2315  being processed
# 23150  being processed
# 23151  being processed
# 23152  being processed
# 23153  being processed
# 23154  being processed
# 23155  being processed
# 23157  being processed
# 23159  being processed
# 2316  being processed
# 23160  being processed
# 23161  being processed
# 23162  being processed
# 23165  being processed
# 23166  being processed
# 23167  being processed
# 23169  being processed
# 2317  being processed
# 23170  being processed
# 23171  being processed
# 23173  being processed
# 23174  being processed
# 23175  being processed
# 23177  being processed
# 23178  being processed
# 2318  being processed
# 23180  being processed
# 23181  being processed
# 23182  being processed
# 23184  being processed
# 23185  being processed
# 23188  being processed
# 2319  being processed
# 23190  being processed
# 23191  being processed
# 23192  being processed
# 23193  being processed
# 23194  being processed
# 23196  being processed
# 23197  being processed
# 23198  being processed
# 23199  being processed
# 23200  being processed
# 23201  being processed
# 23202  being processed
# 23203  being processed
# 23204  being processed
# 23205  being processed
# 23206  being processed
# 23207  being processed
# 23208  being processed
# 23209  being processed
# 23211  being processed
# 23212  being processed
# 23213  being processed
# 23214  being processed
# 23215  being processed
# 23216  being processed
# 23217  being processed
# 23218  being processed
# 23219  being processed
# 2322  being processed
# 23220  being processed
# 23221  being processed
# 23222  being processed
# 23223  being processed
# 23224  being processed
# 23226  being processed
# 23227  being processed
# 23229  being processed
# 23231  being processed
# 23232  being processed
# 23233  being processed
# 23234  being processed
# 23235  being processed
# 23236  being processed
# 23237  being processed
# 23238  being processed
# 23239  being processed
# 2324  being processed
# 23240  being processed
# 23241  being processed
# 23242  being processed
# 23243  being processed
# 23244  being processed
# 23245  being processed
# 23247  being processed
# 23249  being processed
# 23251  being processed
# 23252  being processed
# 23253  being processed
# 23257  being processed
# 23259  being processed
# 23260  being processed
# 23261  being processed
# 23262  being processed
# 23263  being processed
# 23264  being processed
# 23266  being processed
# 23268  being processed
# 23269  being processed
# 2327  being processed
# 23270  being processed
# 23271  being processed
# 23272  being processed
# 23273  being processed
# 23274  being processed
# 23275  being processed
# 23276  being processed
# 23277  being processed
# 23278  being processed
# 23279  being processed
# 2328  being processed
# 23281  being processed
# 23282  being processed
# 23284  being processed
# 23285  being processed
# 23286  being processed
# 23287  being processed
# 23288  being processed
# 23289  being processed
# 23290  being processed
# 23291  being processed
# 23292  being processed
# 23293  being processed
# 23294  being processed
# 23295  being processed
# 23296  being processed
# 23297  being processed
# 23298  being processed
# 23299  being processed
# 233  being processed
# 23300  being processed
# 23304  being processed
# 23305  being processed
# 23306  being processed
# 23309  being processed
# 23310  being processed
# 23311  being processed
# 23313  being processed
# 23314  being processed
# 23315  being processed
# 23316  being processed
# 23317  being processed
# 23318  being processed
# 23319  being processed
# 2332  being processed
# 23321  being processed
# 23322  being processed
# 23325  being processed
# 23326  being processed
# 23327  being processed
# 23328  being processed
# 23329  being processed
# 23330  being processed
# 23331  being processed
# 23332  being processed
# 23334  being processed
# 23335  being processed
# 23338  being processed
# 23340  being processed
# 23341  being processed
# 23342  being processed
# 23343  being processed
# 23344  being processed
# 23345  being processed
# 23346  being processed
# 23347  being processed
# 23348  being processed
# 23349  being processed
# 2335  being processed
# 23350  being processed
# 23351  being processed
# 23352  being processed
# 23353  being processed
# 23354  being processed
# 23355  being processed
# 23356  being processed
# 23358  being processed
# 2336  being processed
# 23360  being processed
# 23361  being processed
# 23362  being processed
# 23363  being processed
# 23364  being processed
# 23365  being processed
# 23366  being processed
# 23367  being processed
# 23368  being processed
# 23369  being processed
# 2337  being processed
# 23370  being processed
# 23371  being processed
# 23372  being processed
# 23373  being processed
# 23374  being processed
# 23375  being processed
# 23376  being processed
# 23377  being processed
# 23378  being processed
# 2338  being processed
# 23381  being processed
# 23382  being processed
# 23383  being processed
# 23384  being processed
# 23387  being processed
# 23388  being processed
# 23389  being processed
# 2339  being processed
# 23390  being processed
# 23391  being processed
# 23392  being processed
# 23393  being processed
# 23394  being processed
# 23395  being processed
# 23396  being processed
# 23397  being processed
# 23398  being processed
# 23399  being processed
# 234  being processed
# 2340  being processed
# 23401  being processed
# 23402  being processed
# 23404  being processed
# 23405  being processed
# 23406  being processed
# 23407  being processed
# 23408  being processed
# 23409  being processed
# 2341  being processed
# 23410  being processed
# 23411  being processed
# 23412  being processed
# 23413  being processed
# 23414  being processed
# 23415  being processed
# 23416  being processed
# 23420  being processed
# 23421  being processed
# 23422  being processed
# 23423  being processed
# 23424  being processed
# 23425  being processed
# 23426  being processed
# 23427  being processed
# 23428  being processed
# 23429  being processed
# 2343  being processed
# 23430  being processed
# 23431  being processed
# 23432  being processed
# 23433  being processed
# 23434  being processed
# 23437  being processed
# 2344  being processed
# 23441  being processed
# 23443  being processed
# 23444  being processed
# 23445  being processed
# 23447  being processed
# 23448  being processed
# 2345  being processed
# 23450  being processed
# 23451  being processed
# 23452  being processed
# 23453  being processed
# 23454  being processed
# 23456  being processed
# 23457  being processed
# 23458  being processed
# 23459  being processed
# 23460  being processed
# 23461  being processed
# 23462  being processed
# 23463  being processed
# 23465  being processed
# 23466  being processed
# 23467  being processed
# 23468  being processed
# 2347  being processed
# 23470  being processed
# 23473  being processed
# 23474  being processed
# 23475  being processed
# 23476  being processed
# 23478  being processed
# 23479  being processed
# 23480  being processed
# 23481  being processed
# 23482  being processed
# 23484  being processed
# 23485  being processed
# 23486  being processed
# 23487  being processed
# 23488  being processed
# 23489  being processed
# 2349  being processed
# 23491  being processed
# 23492  being processed
# 23494  being processed
# 23495  being processed
# 23496  being processed
# 23497  being processed
# 23498  being processed
# 23499  being processed
# 2350  being processed
# 23500  being processed
# 23502  being processed
# 23503  being processed
# 23504  being processed
# 23505  being processed
# 23506  being processed
# 23508  being processed
# 23509  being processed
# 23510  being processed
# 23511  being processed
# 23512  being processed
# 23516  being processed
# 23517  being processed
# 23518  being processed
# 23519  being processed
# 23520  being processed
# 23521  being processed
# 23522  being processed
# 23523  being processed
# 23524  being processed
# 23525  being processed
# 23526  being processed
# 23527  being processed
# 23528  being processed
# 2353  being processed
# 23530  being processed
# 23532  being processed
# 23533  being processed
# 23534  being processed
# 23535  being processed
# 23536  being processed
# 23537  being processed
# 23539  being processed
# 2354  being processed
# 23540  being processed
# 23541  being processed
# 23542  being processed
# 23543  being processed
# 23544  being processed
# 23545  being processed
# 23546  being processed
# 23547  being processed
# 23548  being processed
# 23549  being processed
# 2355  being processed
# 23550  being processed
# 23552  being processed
# 23553  being processed
# 23554  being processed
# 23555  being processed
# 23557  being processed
# 23558  being processed
# 23559  being processed
# 2356  being processed
# 23560  being processed
# 23561  being processed
# 23562  being processed
# 23563  being processed
# 23565  being processed
# 23566  being processed
# 23568  being processed
# 23569  being processed
# 2357  being processed
# 23572  being processed
# 23573  being processed
# 23576  being processed
# 23577  being processed
# 23578  being processed
# 23579  being processed
# 2358  being processed
# 23580  being processed
# 23581  being processed
# 23583  being processed
# 23586  being processed
# 23587  being processed
# 23588  being processed
# 23589  being processed
# 2359  being processed
# 23590  being processed
# 23591  being processed
# 23592  being processed
# 23593  being processed
# 23595  being processed
# 23597  being processed
# 23598  being processed
# 23599  being processed
# 236  being processed
# 2360  being processed
# 23600  being processed
# 23601  being processed
# 23602  being processed
# 23603  being processed
# 23605  being processed
# 23607  being processed
# 23608  being processed
# 23609  being processed
# 2361  being processed
# 23610  being processed
# 23611  being processed
# 23612  being processed
# 23613  being processed
# 23614  being processed
# 23615  being processed
# 23616  being processed
# 23617  being processed
# 23618  being processed
# 23619  being processed
# 2362  being processed
# 23620  being processed
# 23621  being processed
# 23623  being processed
# 23624  being processed
# 23625  being processed
# 23626  being processed
# 23628  being processed
# 23629  being processed
# 2363  being processed
# 23630  being processed
# 23631  being processed
# 23632  being processed
# 23633  being processed
# 23634  being processed
# 23635  being processed
# 23636  being processed
# 23637  being processed
# 23638  being processed
# 23639  being processed
# 2364  being processed
# 23640  being processed
# 23641  being processed
# 23642  being processed
# 23643  being processed
# 23644  being processed
# 23645  being processed
# 23646  being processed
# 23648  being processed
# 2365  being processed
# 23650  being processed
# 23652  being processed
# 23656  being processed
# 23657  being processed
# 23658  being processed
# 23659  being processed
# 2366  being processed
# 23661  being processed
# 23662  being processed
# 23663  being processed
# 23664  being processed
# 23665  being processed
# 23666  being processed
# 23667  being processed
# 23669  being processed
# 2367  being processed
# 23670  being processed
# 23673  being processed
# 23674  being processed
# 23675  being processed
# 23676  being processed
# 23677  being processed
# 23679  being processed
# 2368  being processed
# 23680  being processed
# 23681  being processed
# 23682  being processed
# 23683  being processed
# 23684  being processed
# 23685  being processed
# 23687  being processed
# 23688  being processed
# 23689  being processed
# 2369  being processed
# 23690  being processed
# 23691  being processed
# 23692  being processed
# 23693  being processed
# 23694  being processed
# 23695  being processed
# 23696  being processed
# 23697  being processed
# 23698  being processed
# 23699  being processed

# %%
df = pd.read_csv("s3://" + datadir + "/plantclef.csv")
df.head(5)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, role, obs_id, class_id, date, family, genus, species, latitude, longitude]
# Index: []
