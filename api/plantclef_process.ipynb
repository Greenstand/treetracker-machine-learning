# %%
import os
from s3fs.core import S3FileSystem
from xml.etree import ElementTree as ET
import pandas as pd


os.environ['AWS_CONFIG_FILE'] = 'aws_config.ini'

fs = S3FileSystem(anon=False)
bucket = 'treetracker-training-images'
datadir = os.path.join(bucket, "PlantCLEF_2016")

# %%
def parse_xml_s3path(s3path):
    '''
    Parse and return a PlantCLEF XML file given a valid s3path
    '''
    if os.path.splitext(s3path)[1] == ".xml": 
        with fs.open(s3path) as file:
            tree = ET.parse(file)
            species = tree.find("Species").text
            family = tree.find("Family").text
            genus = tree.find("Genus").text
            class_id = tree.find("ClassId").text
            obs_id = tree.find("ObservationId").text
            date = tree.find("Date").text
            role = tree.find("LearnTag").text
            latitude = tree.find("Latitude").text
            longitude = tree.find("Longitude").text
            return (role, obs_id, class_id, date, family, genus, species, latitude, longitude)
    else:
        pass

def generate_plantclef_csv(write_csv, batch_size=100):
    '''
    Collects metadata from PlantCLEF 2016 and creates csv file
    '''
    linkings_dict = {}
    if fs.exists(write_csv):
        already_done = dict.fromkeys(pd.read_csv(write_csv).index.values)
        count = len(already_done)
    else:
        already_done = []
        count = 0
    for f, e, d in fs.walk(datadir):
        for path in d:
            if os.path.splitext(path)[1] == ".jpg": # Image file
                base = os.path.splitext(path)[0]
                fullpath = os.path.join(f, base)
                xmlpath = fullpath + ".xml"
                count += 1
                if count % batch_size == 0:
                    linkings = pd.DataFrame.from_dict(linkings_dict, orient="index")
                    if count <= batch_size and len(already_done) == 0: # first run ever
                        print ("Creating csv")
                        linkings.columns = ["role", "obs_id", "class_id", "date", "family", "genus", "species", "latitude", "longitude"]
                        linkings.to_csv(write_csv, mode='w')
                    else:
                        print ("%d done appending to %s"%(count, write_csv))
                        linkings.to_csv(write_csv, mode='a', header=False) # append batch-wise
                    linkings_dict.clear()
                if not fs.exists(xmlpath):
                    print ("File ", xmlpath , " does not exist!")
                if already_done.get(base, 0) == 0: # makes sure we're not processing something that already has been processed
                    linkings_dict [base] = parse_xml_s3path(xmlpath)
                
    return pd.read_csv(write_csv)

# %%
generate_plantclef_csv(write_csv="s3://" + datadir + "/plantclef.csv")
# Out:
# 600  done
# 600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 700  done
# 700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 800  done
# 800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 900  done
# 900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1000  done
# 1000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1100  done
# 1100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1200  done
# 1200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1300  done
# 1300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1400  done
# 1400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1500  done
# 1500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1600  done
# 1600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1700  done
# 1700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1800  done
# 1800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 1900  done
# 1900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2000  done
# 2000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2100  done
# 2100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2200  done
# 2200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2300  done
# 2300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2400  done
# 2400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2500  done
# 2500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2600  done
# 2600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2700  done
# 2700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2800  done
# 2800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 2900  done
# 2900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3000  done
# 3000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3100  done
# 3100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3200  done
# 3200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3300  done
# 3300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3400  done
# 3400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3500  done
# 3500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3600  done
# 3600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3700  done
# 3700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3800  done
# 3800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 3900  done
# 3900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4000  done
# 4000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4100  done
# 4100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4200  done
# 4200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4300  done
# 4300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4400  done
# 4400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4500  done
# 4500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4600  done
# 4600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4700  done
# 4700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4800  done
# 4800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 4900  done
# 4900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5000  done
# 5000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5100  done
# 5100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5200  done
# 5200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5300  done
# 5300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5400  done
# 5400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5500  done
# 5500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5600  done
# 5600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5700  done
# 5700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5800  done
# 5800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 5900  done
# 5900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6000  done
# 6000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6100  done
# 6100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6200  done
# 6200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6300  done
# 6300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6400  done
# 6400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6500  done
# 6500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6600  done
# 6600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6700  done
# 6700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6800  done
# 6800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 6900  done
# 6900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7000  done
# 7000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7100  done
# 7100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7200  done
# 7200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7300  done
# 7300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7400  done
# 7400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7500  done
# 7500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7600  done
# 7600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7700  done
# 7700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7800  done
# 7800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 7900  done
# 7900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8000  done
# 8000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8100  done
# 8100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8200  done
# 8200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8300  done
# 8300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8400  done
# 8400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8500  done
# 8500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8600  done
# 8600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8700  done
# 8700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8800  done
# 8800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 8900  done
# 8900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9000  done
# 9000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9100  done
# 9100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9200  done
# 9200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9300  done
# 9300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9400  done
# 9400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9500  done
# 9500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9600  done
# 9600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9700  done
# 9700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9800  done
# 9800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 9900  done
# 9900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10000  done
# 10000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10100  done
# 10100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10200  done
# 10200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10300  done
# 10300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10400  done
# 10400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10500  done
# 10500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10600  done
# 10600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10700  done
# 10700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10800  done
# 10800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 10900  done
# 10900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11000  done
# 11000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11100  done
# 11100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11200  done
# 11200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11300  done
# 11300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11400  done
# 11400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11500  done
# 11500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11600  done
# 11600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11700  done
# 11700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11800  done
# 11800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 11900  done
# 11900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12000  done
# 12000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12100  done
# 12100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12200  done
# 12200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12300  done
# 12300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12400  done
# 12400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12500  done
# 12500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12600  done
# 12600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12700  done
# 12700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12800  done
# 12800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 12900  done
# 12900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13000  done
# 13000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13100  done
# 13100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13200  done
# 13200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13300  done
# 13300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13400  done
# 13400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13500  done
# 13500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13600  done
# 13600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13700  done
# 13700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13800  done
# 13800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 13900  done
# 13900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14000  done
# 14000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14100  done
# 14100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14200  done
# 14200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14300  done
# 14300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14400  done
# 14400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14500  done
# 14500 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14600  done
# 14600 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14700  done
# 14700 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14800  done
# 14800 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 14900  done
# 14900 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 15000  done
# 15000 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 15100  done
# 15100 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 15200  done
# 15200 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 15300  done
# 15300 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# 15400  done
# 15400 done appending to s3://treetracker-training-images/PlantCLEF_2016/plantclef.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f0fbe512670d> in <module>
# ----> 1 generate_plantclef_csv(write_csv="s3://" + datadir + "/plantclef.csv")
#
# <ipython-input-7-0bf9ac626327> in generate_plantclef_csv(write_csv, batch_size)
#      51                     print ("File ", xmlpath , " does not exist!")
#      52                 if already_done.get(base, 0) == 0: # makes sure we're not processing something that already has been processed
# ---> 53                     linkings_dict [base] = parse_xml_s3path(xmlpath)
#      54
#      55     return pd.read_csv(write_csv)
#
# <ipython-input-7-0bf9ac626327> in parse_xml_s3path(s3path)
#       4     '''
#       5     if os.path.splitext(s3path)[1] == ".xml":
# ----> 6         with fs.open(s3path) as file:
#       7             tree = ET.parse(file)
#       8             species = tree.find("Species").text
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     722                 autocommit=ac,
#     723                 cache_options=cache_options,
# --> 724                 **kwargs
#     725             )
#     726             if not ac:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     376                       version_id=version_id, fill_cache=fill_cache,
#     377                       s3_additional_kwargs=kw, cache_type=cache_type,
# --> 378                       autocommit=autocommit, requester_pays=requester_pays)
#     379
#     380     def _lsdir(self, path, refresh=False, max_items=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1095         self.req_kw = {'RequestPayer': 'requester'} if requester_pays else {}
#    1096         super().__init__(s3, path, mode, block_size, autocommit=autocommit,
# -> 1097                          cache_type=cache_type)
#    1098         self.s3 = self.fs  # compatibility
#    1099         if self.writable():
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#     954         if mode == "rb":
#     955             if not hasattr(self, "details"):
# --> 956                 self.details = fs.info(path)
#     957             self.size = self.details["size"]
#     958             self.cache = caches[cache_type](
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3fs/core.py in info(self, path, version_id, refresh)
#     528             try:
#     529                 out = self._call_s3(self.s3.head_object, kwargs, Bucket=bucket,
# --> 530                                     Key=key, **version_id_kw(version_id), **self.req_kw)
#     531                 return {
#     532                     'ETag': out['ETag'],
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     198         additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist,
#     199                                                        **kwargs)
# --> 200         return method(**additional_kwargs)
#     201
#     202     def _get_s3_method_kwargs(self, method, *akwarglist, **kwargs):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     661         else:
#     662             http, parsed_response = self._make_request(
# --> 663                 operation_model, request_dict, request_context)
#     664
#     665         self.meta.events.emit(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     680     def _make_request(self, operation_model, request_dict, request_context):
#     681         try:
# --> 682             return self._endpoint.make_request(operation_model, request_dict)
#     683         except Exception as e:
#     684             self.meta.events.emit(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
# --> 135             request, operation_model, context)
#     136         while self._needs_retry(attempts, operation_model, request_dict,
#     137                                 success_response, exception):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     165         # If no exception occurs then exception is None.
#     166         success_response, exception = self._do_get_response(
# --> 167             request, operation_model)
#     168         kwargs_to_emit = {
#     169             'response_dict': None,
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model)
#     198             http_response = first_non_none_response(responses)
#     199             if http_response is None:
# --> 200                 http_response = self._send(request)
#     201         except HTTPClientError as e:
#     202             return (None, e)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in _send(self, request)
#     267
#     268     def _send(self, request):
# --> 269         return self.http_session.send(request)
#     270
#     271
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/httpsession.py in send(self, request)
#     261                 preload_content=False,
#     262                 decode_content=False,
# --> 263                 chunked=self._chunked(request.headers),
#     264             )
#     265
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/anaconda3/envs/python3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("s3://" + datadir + "/plantclef.csv")
df.head(25)
# Out:
#     Unnamed: 0   role  obs_id  class_id       date            family  \
# 0            1  Train   21782      5810  2013-3-21    Amaryllidaceae
# 1           10  Train   11786      6448  2014-8-22       Orchidaceae
# 2         1000  Train   40480     30040   2011-4-8          Fabaceae
# 3        10000  Train   14235      3529  2013-9-12         Lamiaceae
# 4       100001  Train   33815      4736   2013-6-5          Rosaceae
# 5            1  Train   21782      5810  2013-3-21    Amaryllidaceae
# 6           10  Train   11786      6448  2014-8-22       Orchidaceae
# 7         1000  Train   40480     30040   2011-4-8          Fabaceae
# 8        10000  Train   14235      3529  2013-9-12         Lamiaceae
# 9       100001  Train   33815      4736   2013-6-5          Rosaceae
# 10      100003  Train   31171      6448   1800-1-1       Orchidaceae
# 11      100004  Train   12777      7452   2011-4-1     Polypodiaceae
# 12      100005  Train    3075      3519  2011-8-20         Lamiaceae
# 13      100007  Train   24344     30131   2006-4-5          Oleaceae
# 14      100009  Train    7310     30126   2010-7-5          Moraceae
# 15       10001  Train   37849      4111  2012-9-10       Platanaceae
# 16      100011  Train    8593      4969   2010-8-2          Rosaceae
# 17      100012  Train    6215      2629  2009-7-25       Droseraceae
# 18      100014  Train   14612      5483   2011-7-5  Scrophulariaceae
# 19      100016  Train   30648      1609  2013-5-27      Brassicaceae
# 20      100017  Train   33097      4840   2012-5-1          Rosaceae
# 21      100018  Train   11610     14881  2004-6-11    Caprifoliaceae
# 22      100019  Train   15010      8527  2009-4-24        Asteraceae
# 23       10002  Train   12969      1973  2012-3-25         Adoxaceae
# 24      100022  Train   34039     30471   1800-1-1       Orchidaceae
#
#           genus                               species  latitude  longitude
# 0     Narcissus                Narcissus dubius Gouan  42.98235    3.01486
# 1     Epipactis  Epipactis atrorubens (Hoffm.) Besser  45.34137    5.81565
# 2        Cercis                Cercis siliquastrum L.       NaN        NaN
# 3   Clinopodium        Clinopodium nepeta (L.) Kuntze       NaN        NaN
# 4       Cydonia                 Cydonia oblonga Mill.  48.84059    2.36158
# 5     Narcissus                Narcissus dubius Gouan  42.98235    3.01486
# 6     Epipactis  Epipactis atrorubens (Hoffm.) Besser  45.34137    5.81565
# 7        Cercis                Cercis siliquastrum L.       NaN        NaN
# 8   Clinopodium        Clinopodium nepeta (L.) Kuntze       NaN        NaN
# 9       Cydonia                 Cydonia oblonga Mill.  48.84059    2.36158
# 10    Epipactis  Epipactis atrorubens (Hoffm.) Besser       NaN        NaN
# 11   Polypodium                 Polypodium vulgare L.  43.62870    3.36674
# 12        Ajuga                      Ajuga reptans L.       NaN        NaN
# 13     Fraxinus                 Fraxinus excelsior L.  49.49396    5.44031
# 14        Ficus                       Ficus carica L.  43.60818    3.87945
# 15     Platanus                Platanus orientalis L.       NaN        NaN
# 16        Rubus               Rubus ulmifolius Schott  47.74763   -0.42975
# 17      Drosera               Drosera rotundifolia L.  44.68182    2.91464
# 18    Verbascum         Verbascum pulverulentum Vill.       NaN        NaN
# 19     Lepidium                     Lepidium draba L.  43.66086    3.55753
# 20       Prunus                Prunus laurocerasus L.       NaN        NaN
# 21    Valeriana              Valeriana officinalis L.  49.07072   -1.41148
# 22     Achillea               Achillea millefolium L.       NaN        NaN
# 23     Viburnum                     Viburnum tinus L.       NaN        NaN
# 24       Ophrys                  Ophrys scolopax Cav.  43.72436    2.22319
